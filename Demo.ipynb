# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanjawahar/data-science-entry-test/blob/main/Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, GitHub! This is my first commit.")
